# %%
import pandas as pd
train1=pd.read_csv('train_enc.csv')
test1=pd.read_csv('test_enc.csv')

# %%
train1.head()
# Out:
#    Unnamed: 0  Airline  Source  Destination  Additional_Info  Price  month  \
# 0           0        3       0            5                8   3897      3
# 1           1        1       3            0                8   7662      5
# 2           2        4       2            1                8  13882      6
# 3           3        3       3            0                8   6218      5
# 4           4        3       0            5                8  13302      3
#
#    Weekday  Dep_hour  Dep_min  Arrival_hour  Dur_hour  Dur_min  Arrival_min2  \
# 0        3        22       20             1         2       50            10
# 1        2         5       50            13         7       25            15
# 2        0         9       25             4        19        0            25
# 3        4        18        5            23         5       25            30
# 4        4        16       50            21         4       45            35
#
#    Stop1  Stop2  Stop3  Stop4  Total_stops1
# ...

# %%
test1.head()
# Out:
#    Unnamed: 0  Airline  Source  Destination  Additional_Info  month  Weekday  \
# 0           0        4       2            1                5      6        4
# 1           1        3       3            0                5      5        4
# 2           2        4       2            1                3      5        5
# 3           3        6       2            1                5      5        5
# 4           4        0       0            2                5      6        1
#
#    Dep_hour  Dep_min  Arrival_hour  Dur_hour  Dur_min  Arrival_min2  Stop1  \
# 0        17       30             4        10       55            25      3
# 1         6       20            10         4        0            20      2
# 2        19       15            19        23       45             0      3
# 3         8        0            21        13        0             0      3
# 4        23       55             2         2       50            45      0
#
#    Stop2  Stop3  Stop4  Total_stops1
# ...

# %%
List = train1.agg(['skew','kurtosis','std','mean','min','median','max'])
print(List)
# Out:
#             Unnamed: 0    Airline    Source  Destination  Additional_Info  \
# skew          0.000274   0.731020 -0.424188     1.244370        -1.779539
# kurtosis     -1.200002   0.366593 -0.662903     0.632757         2.507634
# std        3084.122455   2.352025  1.177165     1.474836         1.214296
# mean       5340.547702   3.966483  1.952064     1.436008         7.392941
# min           0.000000   0.000000  0.000000     0.000000         0.000000
# median     5340.000000   4.000000  2.000000     1.000000         8.000000
# max       10682.000000  11.000000  4.000000     5.000000         9.000000
#
#                  Price     month   Weekday   Dep_hour    Dep_min  \
# skew          1.813100 -0.387625 -0.065364   0.113075   0.167415
# kurtosis     13.310420 -1.318597 -1.299123  -1.194960  -1.292469
# std        4611.075357  1.164345  2.052606   5.748989  18.767046
# mean       9086.443123  4.708735  2.996910  12.490684  24.406891
# ...

# %%
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize']=(15,10)

import matplotlib
matplotlib.style.use('ggplot')

# %%
month_price = pd.crosstab(index = train1["month"],  # Make a crosstab
                              columns="Price",normalize=True)      # Name the count column

month_price
# Out:
# col_0     Price
# month
# 3      0.254939
# 4      0.101021
# 5      0.324408
# 6      0.319633

# %%
month_price.plot.bar()

# %%
Stop_price = pd.crosstab(index = train1["Total_stops1"],  # Make a crosstab
                              columns="Price",normalize=True)      # Name the count column

Stop_price
# Out:
# col_0            Price
# Total_stops1
# 0             0.326842
# 1             0.526636
# 2             0.142215
# 3             0.004213
# 4             0.000094

# %%
Stop_price.plot.bar()

# %%
Durh_price = pd.crosstab(index = train1["Dur_hour"],  # Make a crosstab
                              columns="Price",normalize=True)      # Name the count column

Durh_price
# Out:
# col_0        Price
# Dur_hour
# 1         0.058141
# 2         0.224885
# 3         0.046906
# 4         0.020785
# 5         0.045033
# 6         0.031832
# 7         0.045595
# 8         0.039697
# 9         0.041663
# 10        0.033237
# 11        0.034173
# 12        0.040071
# 13        0.038105
# 14        0.031551
# 15        0.025091
# 16        0.021908
# 17        0.012078
# 18        0.013201
# 19        0.012546
# 20        0.015167
# 21        0.018350
# 22        0.020410
# 23        0.024717
# 24        0.018444
# 25        0.017414
# 26        0.022563
# 27        0.016759
# 28        0.008801
# 29        0.006086
# 30        0.004588
# 31        0.000562
# 32        0.000843
# 33        0.001217
# 34        0.000749
# 35        0.000655
# 36        0.000655
# 37        0.001592
# 38        0.003183
# 39        0.000187
# 40        0.000094
# 41        0.000094
# 42        0.000187
# 47        0.000187

# %%
Durh_price.plot.bar()

# %%
train1.describe()
# Out:
#          Unnamed: 0       Airline        Source   Destination  \
# count  10681.000000  10681.000000  10681.000000  10681.000000
# mean    5340.547702      3.966483      1.952064      1.436008
# std     3084.122455      2.352025      1.177165      1.474836
# min        0.000000      0.000000      0.000000      0.000000
# 25%     2670.000000      3.000000      2.000000      0.000000
# 50%     5340.000000      4.000000      2.000000      1.000000
# 75%     8011.000000      4.000000      3.000000      2.000000
# max    10682.000000     11.000000      4.000000      5.000000
#
#        Additional_Info         Price         month       Weekday  \
# count     10681.000000  10681.000000  10681.000000  10681.000000
# mean          7.392941   9086.443123      4.708735      2.996910
# std           1.214296   4611.075357      1.164345      2.052606
# min           0.000000   1759.000000      3.000000      0.000000
# 25%           8.000000   5277.000000      3.000000      1.000000
# ...

# %%
data1['']
